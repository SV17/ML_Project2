# %%
# for image recogonition 
import cv2
# for dataframes
import pandas as pd
# to print graphs
import matplotlib.pyplot as plt
# perform numeric operations
import numpy as np
# to print graphs on the same window
# %matplotlib inline
# to make matplotlib coding easy
import seaborn as sns
# object of sns
sns.set()

# %%
image = cv2.imread('hunk.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (808L, 766L, 3L)

# %%
plt.figure()
plt.axis("off")
plt.imshow(image)

# %%
image.shape
# Out:
# (808L, 766L, 3L)

# %%
image = image.reshape((image.shape[0] * image.shape[1], 3))
print image
print image.shape
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]
# (618928L, 3L)

# %%
from sklearn.cluster import KMeans
K = 3
clf = KMeans(n_clusters=K)
clf.fit(image)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#initialising the label dictionary#initial 
label = [0, 0, 0]

#finding count of data in each cluster
for x in clf.labels_:
    label[x] += 1

#Total Number of data points
label_sum = image.shape[0]

#converting to percentage
label = [float(x) / label_sum for x in label]
print label
# Out:
# [0.5926585967996277, 0.3133773233720239, 0.09396407982834837]

# %%
import webcolors

centroids = [x.astype("uint8").tolist() for x in clf.cluster_centers_]

clr = [webcolors.rgb_to_hex(c) for c in centroids]

plt.pie(label, colors=clr, shadow=True) 
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Importing 10 images and plotting the most common dominant colors

# %%
# data frame for dominant color in each image 
domc = pd.DataFrame({
    'Image name': [],
    'Dominant colour percentage': [],
    'Color': []
})

# %%
# list to store dominant color realated data
data = []
# fetching images in the loop
for i in range(1,11):
    
    print '****************************************************************************** '
    print '****************************** IMAGE %s *************************************** ' %i
    print '****************************************************************************** '
    
    image_name = 'C:\Users\SHIVA VERMA\Anaconda2\Dominant_color_case_study\Dominant_Color_Data_Set\image ' + str(i) + '.jpg'
    
    # reading an image
    image = cv2.imread(image_name)
    
    # convert image pixel values from BGR to RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # to display width x height x channel
    print 'Image shape: '+str(image.shape)
    
    '''
    # to display image
    plt.figure(i)
    # setting image axis
    plt.axis("off")
    # displaying image
    plt.imshow(image)
    '''
    
    # converting 3D image array to 1D
    image = image.reshape((image.shape[0]*image.shape[1],3))
    
    # print image
    print 'Shape of image after image reshape: '+str(image.shape)
    
    # declaring object of KMeans
    kmeans = KMeans(n_clusters=3, random_state=0).fit(image)

    # initialising the label dictionary
    label = [0,0,0]

    # finding count of data in each cluster
    for x in kmeans.labels_:
        label[x] += 1

    # total number of data points
    label_sum = image.shape[0]

    #converting to percentage
    label = [round((float(x)/label_sum)*100, 2) for x in label]
    m = max(label)
    y = label.index(m)
    print 'Percentage of different colours: '+str(label)

    # print kmeans.cluster_centers_

    # color values of each centroid pixels of different clusters
    centroids = [x.astype('uint8').tolist() for x in kmeans.cluster_centers_]
    print centroids
    
    # covert pixel RGB color intensity values to hex code
    clr = [webcolors.rgb_to_hex(c) for c in centroids]
    print 'colours hex codes: '+ str(clr)
    dc = clr[y]
    
    # ploting pie chart
    plt.pie(label, colors=clr, shadow=True, autopct='%1.1f%%')
    plt.axis('equal')
    plt.show()
    
    # appending data to list
    l = []
    l.append('Image'+str(i))
    l.append(m)
    l.append(dc)
    
    # appending list all the image details to a list
    data.append(l)
    
    # appending data to dataframe
    domc = domc.append(pd.DataFrame({
        'Image name' : [data[i-1][0]],
        'Dominant colour percentage' : [data[i-1][1]],
        'Color' : [data[i-1][2]]
    }))
# Out:
# ******************************************************************************
# ****************************** IMAGE 1 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [47.19, 29.6, 23.21]
# [[48, 50, 91], [217, 212, 208], [166, 89, 92]]
# colours hex codes: [u'#30325b', u'#d9d4d0', u'#a6595c']
# ******************************************************************************
# ****************************** IMAGE 2 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [58.66, 27.26, 14.08]
# [[48, 48, 35], [214, 204, 199], [116, 101, 80]]
# colours hex codes: [u'#303023', u'#d6ccc7', u'#746550']
# ******************************************************************************
# ****************************** IMAGE 3 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [67.98, 16.83, 15.2]
# [[251, 250, 248], [216, 181, 156], [92, 76, 71]]
# colours hex codes: [u'#fbfaf8', u'#d8b59c', u'#5c4c47']
# ******************************************************************************
# ****************************** IMAGE 4 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [63.13, 14.95, 21.93]
# [[140, 134, 136], [107, 72, 78], [38, 27, 32]]
# colours hex codes: [u'#8c8688', u'#6b484e', u'#261b20']
# ******************************************************************************
# ****************************** IMAGE 5 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [9.61, 31.13, 59.26]
# [[193, 160, 147], [50, 43, 44], [251, 251, 250]]
# colours hex codes: [u'#c1a093', u'#322b2c', u'#fbfbfa']
# ******************************************************************************
# ****************************** IMAGE 6 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [71.48, 23.81, 4.7]
# [[240, 239, 238], [18, 22, 45], [193, 143, 120]]
# colours hex codes: [u'#f0efee', u'#12162d', u'#c18f78']
# ******************************************************************************
# ****************************** IMAGE 7 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [65.16, 25.8, 9.03]
# [[237, 234, 235], [31, 31, 27], [208, 160, 127]]
# colours hex codes: [u'#edeaeb', u'#1f1f1b', u'#d0a07f']
# ******************************************************************************
# ****************************** IMAGE 8 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [28.7, 56.89, 14.41]
# [[116, 115, 122], [40, 39, 49], [201, 189, 193]]
# colours hex codes: [u'#74737a', u'#282731', u'#c9bdc1']
# ******************************************************************************
# ****************************** IMAGE 9 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [58.61, 32.07, 9.32]
# [[44, 45, 64], [240, 240, 240], [196, 175, 170]]
# colours hex codes: [u'#2c2d40', u'#f0f0f0', u'#c4afaa']
# ******************************************************************************
# ****************************** IMAGE 10 ***************************************
# ******************************************************************************
# Image shape: (640L, 480L, 3L)
# Shape of image after image reshape: (307200L, 3L)
# Percentage of different colours: [29.6, 21.62, 48.78]
# [[71, 18, 21], [154, 145, 146], [133, 46, 52]]
# colours hex codes: [u'#471215', u'#9a9192', u'#852e34']

# %%
print domc
# Out:
#      Color  Dominant colour percentage Image name
# 0  #30325b                       47.19     Image1
# 0  #303023                       58.66     Image2
# 0  #fbfaf8                       67.98     Image3
# 0  #8c8688                       63.13     Image4
# 0  #fbfbfa                       59.26     Image5
# 0  #f0efee                       71.48     Image6
# 0  #edeaeb                       65.16     Image7
# 0  #282731                       56.89     Image8
# 0  #2c2d40                       58.61     Image9
# 0  #852e34                       48.78    Image10

# %%
# most dominant colour in each picture
sns.barplot(data=domc, x='Image name', y='Dominant colour percentage')

# %%
# list of average percentage of different colours found in all the 10 images
g_Color = [['Blue',20.84],['Black',11.5],['White',29.61],['Red',10.16],['Grey',18.47],['Green',1.41],
           ['Salmon',5.5],['Brown',2.45]]

# converting list of list to a dataframe to print graph
avg_graph = pd.DataFrame(g_Color,columns=['Color','Average'],dtype=float)
print avg_graph
# Out:
#     Color  Average
# 0    Blue    20.84
# 1   Black    11.50
# 2   White    29.61
# 3     Red    10.16
# 4    Grey    18.47
# 5   Green     1.41
# 6  Salmon     5.50
# 7   Brown     2.45

# %%
# plotting bar graph for frequent colours in different images vs their percentage in all the 10 images 
sns.barplot(x='Color',y='Average',data=avg_graph)
